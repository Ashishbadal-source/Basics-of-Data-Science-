# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('concrete_data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
data.shape
# Out:
# (1030, 9)

# %%
data['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# for a Sample 
sample_distribution=[]
samples =[]
for i in range(1000):
    samples.append(data['Age'].sample(500).values.tolist())

# %%
np.array(samples).shape
# Out:
# (1000, 500)

# %%
sampling_means = np.array(samples).mean(axis=1)

# %%
sampling_means
# Out:
# array([44.578, 42.708, 47.182, 43.09 , 46.184, 45.428, 42.806, 45.908,
#        44.724, 43.746, 47.252, 44.47 , 48.506, 41.312, 49.296, 45.454,
#        48.226, 45.734, 45.54 , 46.68 , 41.854, 44.524, 44.974, 43.714,
#        45.862, 45.548, 44.184, 49.172, 46.464, 45.454, 47.062, 42.888,
#        48.602, 47.032, 47.938, 46.514, 46.836, 43.122, 46.03 , 43.704,
#        42.638, 45.382, 45.278, 46.216, 45.398, 46.11 , 45.342, 46.472,
#        44.472, 43.622, 46.316, 45.924, 41.066, 46.88 , 48.612, 48.004,
#        47.01 , 43.65 , 44.152, 42.898, 46.578, 44.182, 44.812, 47.716,
#        42.784, 46.472, 43.318, 45.79 , 44.454, 43.676, 45.772, 46.798,
#        46.238, 46.128, 44.792, 47.052, 46.424, 42.81 , 47.214, 46.772,
#        47.278, 44.724, 44.514, 44.57 , 45.344, 44.78 , 46.35 , 44.046,
#        38.586, 50.072, 46.608, 46.88 , 48.944, 45.946, 43.88 , 43.722,
#        43.036, 44.396, 44.862, 45.692, 49.858, 47.288, 47.854, 46.422,
# ...

# %%
import seaborn as sns
import math

# %%
sns.kdeplot(sampling_means)
# Out:
# <Axes: ylabel='Density'>

# %%
sampling_means.mean()
# Out:
# np.float64(45.68743799999999)

# %%
data['Age'].mean()
# Out:
# np.float64(45.662135922330094)

# %%
sampling_means.var()
# Out:
# np.float64(4.107230064156)

# %%
data['Age'].var()
# Out:
# 3990.4377291555465

# %%
3990.4377/500
# Out:
# 7.9808753999999995

# %%
sampling_means.std()
# Out:
# np.float64(2.0266302238336427)

# %%
data['Age'].std()
# Out:
# 63.169911581033155

# %%
63.1699/(math.sqrt(500))
# Out:
# 2.825043810637279

# %%
lower_limit = sampling_means.mean() -(2*(sampling_means.var()))
upper_limit = sampling_means.mean() +(2*(sampling_means.var()))

# %%
print(f"the range of the correct mean is : {lower_limit} to {upper_limit}")
# Out:
# the range of the correct answer is : 37.472977871687995 to 53.90189812831199
