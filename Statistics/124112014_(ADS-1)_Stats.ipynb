# %% [markdown]
# # Ashish kumar
# #  124112014
# # ADS - 01

# %% [markdown]
# # Task-1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import scipy as sp

# %% [markdown]
# # Binomial distribution

# %%
def fact(x):
    result = 1
    for i in range(1, x + 1):
        result *= i
    return result

# %%
def combination(n,r):
    return fact(n)//(fact(r)*fact(n-r))

# %%
n = 20
p=0.5
x = np.arange(0, n+1)
list=[]
for x in range(n+1):
    list.append(combination(n,x)*(p**x)*(1-p)**(n-x))
    
plt.vlines(np.arange(0, n+1), 0, list, colors='b', lw=5)
plt.plot(np.arange(0, n+1), list, 'bo', ms=8)
plt.title('Binomial Distribution n=20, p=0.5')
plt.xlabel('Number of successes')   
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# # Poisson distribution

# %%
from math import exp
n = 30
p = 0.5
k_values = np.arange(0, n + 1)
lambda_val = n * p  

probabilities = []
for k in k_values:
    prob = (exp(-lambda_val) * (lambda_val ** k)) / float(fact(k))
    probabilities.append(prob)

plt.vlines(k_values, 0, probabilities, colors='b', lw=5)
plt.plot(k_values, probabilities, 'bo', ms=8)
plt.xlabel('k')
plt.ylabel('P(X = k)')
plt.title('Poisson Distribution (λ = n * p)')
plt.show()

# %% [markdown]
# # Normal distribution

# %%
import math

n = 20
p = 0.5
mean_value = n * p
standard_deviation = math.sqrt(n * p * (1 - p))

x = np.linspace(0, n, 200)

pdf = (1 / (standard_deviation * math.sqrt(2 * math.pi))) * np.exp(-0.5 * ((x - mean_value) / standard_deviation) ** 2)

plt.plot(x, pdf, 'g-', lw=2)
plt.title('Normal Distribution Approximation')
plt.xlabel('x')
plt.ylabel('Probability Density Function')
plt.show()

# %% [markdown]
# Binomial: Discrete. Values only at integer counts.
#
# Poisson: Discrete. Values only at integer counts.
#
# Normal: Continuous. Density defined for all real x.

# %% [markdown]
# ---> Discrete distributions produce isolated probabilities at integers. Their shape approximates a smooth curve only when n (or λ) is large.
#
# ---> The normal is continuous and smooth. For symmetric parameters (p=0.5) the binomial is symmetric and when variance is moderate/large it looks bell-shaped like the normal.

# %% [markdown]
# # Task 2

# %% [markdown]
# # Binomial to normal

# %%
n = 20
p=0.5
x = np.arange(0, n+1)
list=[]
for x in range(n+1):
    list.append(combination(n,x)*(p**x)*(1-p)**(n-x))
    
plt.vlines(np.arange(0, n+1), 0, list, colors='b', lw=5)
plt.plot(np.arange(0, n+1), list, 'bo', ms=8)

plt.title('Binomial Distribution n=20, p=0.5')
plt.xlabel('Number of successes')   
plt.ylabel('Probability')
plt.show()

# %%
n = 30
p=0.5
x = np.arange(0, n+1)
list=[]
for x in range(n+1):
    list.append(combination(n,x)*(p**x)*(1-p)**(n-x))
    
plt.vlines(np.arange(0, n+1), 0, list, colors='b', lw=5)
plt.plot(np.arange(0, n+1), list, 'bo', ms=8)

plt.title('Binomial Distribution n=30, p=0.5')
plt.xlabel('Number of successes')   
plt.ylabel('Probability')
plt.show()

# %%
n = 100
p=0.5
x = np.arange(0, n+1)
list=[]
for x in range(n+1):
    list.append(combination(n,x)*(p**x)*(1-p)**(n-x))
    
plt.vlines(np.arange(0, n+1), 0, list, colors='b', lw=5)
plt.plot(np.arange(0, n+1), list, 'bo', ms=8)

plt.title('Binomial Distribution n=20, p=0.5')
plt.xlabel('Number of successes')   
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# i)      n = 10: PMF is quite discrete and somewhat spread. Normal curve gives a rough shape but misses individual probabilities. Continuity correction helps but deviations visible.
#
# ii)     n = 30: PMF already looks much more bell-shaped. Normal approximation is close. Continuity correction aligns the integer probabilities better.
#
# iii)     n = 100: PMF closely matches the normal curve. Normal approximation (with or without continuity correction) is very good

# %% [markdown]
# # Task 3

# %% [markdown]
# # Poisson to binomial

# %%
n = 20
p = 0.5
k_values = np.arange(0, n + 1)
lambda_val = n * p  

probabilities = []
for k in k_values:
    probabilities.append((np.exp(-lambda_val) * (lambda_val ** k)) / fact(k))

plt.vlines(k_values, 0, probabilities, colors='b', lw=5)
plt.plot(k_values, probabilities, 'bo', ms=8)
plt.xlabel('k')
plt.ylabel('P(X = k)')
plt.title('Poisson Distribution (λ = n * p)')
plt.show()

# %%
n = 20
p = 0.25
k_values = np.arange(0, n + 1)
lambda_val = n * p  

probabilities = []
for k in k_values:
    probabilities.append((np.exp(-lambda_val) * (lambda_val ** k)) / fact(k))

plt.vlines(k_values, 0, probabilities, colors='b', lw=5)
plt.plot(k_values, probabilities, 'bo', ms=8)
plt.xlabel('k')
plt.ylabel('P(X = k)')
plt.title('Poisson Distribution (λ = n * p)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import factorial as fact, comb as combination

n = 15
p = 0.15
λ = n * p
k = np.arange(0, n + 1)

poisson_pmf = [(np.exp(-λ) * (λ ** i)) / fact(i) for i in k]
binomial_pmf = [combination(n, i) * (p ** i) * ((1 - p) ** (n - i)) for i in k]

plt.figure(figsize=(10,6))
plt.bar(k - 0.18, binomial_pmf, width=0.35, color="#0DE6EE", alpha=0.7, edgecolor='black', label='Binomial (n=15, p=0.15)')
plt.bar(k + 0.18, poisson_pmf, width=0.35, color="#E849DB", alpha=0.6, edgecolor='black', label=f'Poisson (λ={λ:.2f})')

plt.plot(k, binomial_pmf, 'o-', color='navy', lw=2, ms=6)
plt.plot(k, poisson_pmf, 'o--', color='darkred', lw=2, ms=6)

plt.title(f'Poisson Approximation to Binomial Distribution\nn={n}, p={p}, λ={λ:.2f}', fontsize=14, pad=15)
plt.xlabel('k (Number of Successes)', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.xticks(k)
plt.grid(True, linestyle='--', alpha=0.4)

plt.legend(loc='upper right', fontsize=11, frameon=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# i) For n = 100 , p = 0.05, the two PMFs(Binomial and Poisson) almost completely overlap.
#
# ii) Both distributions peak near k=2 (the mean) and decline symmetrically on both sides.
#
# iii) The difference between individual probabilities is very small — visually, the bars nearly coincide.

# %% [markdown]
# when n is large and p is small with λ=np constant, the Poisson distribution is a good approximation of the Binomial distribution.

# %% [markdown]
# # Task 4

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
data = pd.read_csv(url)

# %%
data.head(7)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
sum =0
for i in range(len(data)):
    sum = sum + data.iloc[i]['sepal_length']
mean_sepal_length = sum / len(data)
mean_sepal_length
# Out:
# np.float64(5.843333333333335)

# %%
std =0
for i in range(len(data)):
    std = std + (data.iloc[i]['sepal_length'] - mean_sepal_length)**2  
std = (std / len(data))**0.5
std
# Out:
# np.float64(0.8253012917851409)

# %%
plt.hist(data['sepal_length'], bins=10, color='blue', alpha=0.7)
plt.title('Histogram of Sepal Lengths') 

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10      
p = 0.5      
lambda_val = 3  
sample_size = 1000  

import pandas as pd
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
data = pd.read_csv(url)

mean_normal = data['sepal_length'].mean()
std_normal = data['sepal_length'].std()

binom_samples = np.random.binomial(n, p, sample_size)
poisson_samples = np.random.poisson(lambda_val, sample_size)
normal_samples = np.random.normal(mean_normal, std_normal, sample_size)

def plot_stats(samples, title):
    plt.hist(samples, bins=30, color='red', edgecolor='black')
    plt.title(f'Histogram of {title} samples')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()
    
    mean_val = np.mean(samples)
    var_val = np.var(samples)
    print(f"{title} Mean: {mean_val:.2f}")
    print(f"{title} Variance: {var_val:.2f}\n")

plot_stats(binom_samples, "Binomial")
plot_stats(poisson_samples, "Poisson")
plot_stats(normal_samples, "Normal")
# Out:
# Binomial Mean: 4.90
# Binomial Variance: 2.60
# Poisson Mean: 3.09
# Poisson Variance: 3.06
# Normal Mean: 5.83
# Normal Variance: 0.69

# %% [markdown]
# # Task 5

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import scipy 
import seaborn as sns
import math

# %%
import kagglehub

url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print("Shape:", data.shape)
print("\nColumns:", data.columns.tolist())
# Out:
# Shape: (768, 9)
#
# Columns: ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
data = data.select_dtypes(include=['int64', 'float64'])
cols = data.columns
corr_matrix = pd.DataFrame(index=cols, columns=cols, dtype=float)

for i in cols:
    for j in cols:
        x = data[i].values
        y = data[j].values
        
        mean_x = np.mean(x)
        mean_y = np.mean(y)
        
        numerator = np.sum((x - mean_x) * (y - mean_y))
        denominator = np.sqrt(np.sum((x - mean_x)**2) * np.sum((y - mean_y)**2))
        
        corr = numerator / denominator if denominator != 0 else 0
        corr_matrix.loc[i, j] = corr

print("\nManual Correlation Matrix:")
print(corr_matrix.round(2))
# Out:
# Manual Correlation Matrix:
#                           Pregnancies  Glucose  BloodPressure  SkinThickness  \
# Pregnancies                      1.00     0.13           0.14          -0.08
# Glucose                          0.13     1.00           0.15           0.06
# BloodPressure                    0.14     0.15           1.00           0.21
# SkinThickness                   -0.08     0.06           0.21           1.00
# Insulin                         -0.07     0.33           0.09           0.44
# BMI                              0.02     0.22           0.28           0.39
# DiabetesPedigreeFunction        -0.03     0.14           0.04           0.18
# Age                              0.54     0.26           0.24          -0.11
# Outcome                          0.22     0.47           0.07           0.07
#
#                           Insulin   BMI  DiabetesPedigreeFunction   Age  \
# Pregnancies                 -0.07  0.02                     -0.03  0.54
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix.astype(float), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Manual Correlation Matrix - Diabetes Dataset")
plt.show()

# %%
threshold = 0.9
corr_pairs = corr_matrix.unstack()
high_corr = corr_pairs[(abs(corr_pairs) > threshold) & (abs(corr_pairs) < 1)]
print("\nHighly Correlated Feature Pairs (>|0.9|):")
print(high_corr)

X = data.values
X_meaned = X - np.mean(X, axis=0)
cov_mat = np.cov(X_meaned, rowvar=False)
eigen_values, eigen_vectors = np.linalg.eig(cov_mat)
sorted_index = np.argsort(eigen_values)[::-1]
eigen_values = eigen_values[sorted_index]
eigen_vectors = eigen_vectors[:, sorted_index]
k = 2
eigenvector_subset = eigen_vectors[:, :k]
X_reduced = np.dot(X_meaned, eigenvector_subset)

print("\nOriginal shape:", X.shape)
print("Reduced shape:", X_reduced.shape)
# Out:
# Highly Correlated Feature Pairs (>|0.9|):
# Series([], dtype: float64)
#
# Original shape: (768, 9)
# Reduced shape: (768, 2)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=data['Outcome'], cmap='coolwarm', edgecolor='k', alpha=0.7)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization (2 Components)")
plt.colorbar(label='Diabetes Outcome')
plt.show()

# %%
explained_variance_ratio = eigen_values / np.sum(eigen_values)
print("\nExplained Variance Ratio (Top 2 PCs):")
print(explained_variance_ratio[:2])
# Out:
# Explained Variance Ratio (Top 2 PCs):
# [0.88853359 0.06159289]
