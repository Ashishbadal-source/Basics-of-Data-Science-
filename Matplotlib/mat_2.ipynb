# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('Sepal_Length')
plt.ylabel('Petal_Length')
# Out:
# Text(0, 0.5, 'Petal_Length')

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('Sepal_Length')
plt.ylabel('Petal_Length')
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})  #assigning no. of type of flowers 
iris.sample(5)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12540\3634780589.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})  #assigning no. of type of flowers
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 108  109            6.7           2.5            5.8           1.8        2
# 37    38            4.9           3.1            1.5           0.1        0
# 77    78            6.7           3.0            5.0           1.7        1
# 11    12            4.8           3.4            1.6           0.2        0
# 86    87            6.7           3.1            4.7           1.5        1

# %%
# cmap is for differetn color combinations and alpha is opacity of the color and colorbar() is for that bar near the graph to show level .
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='winter',alpha=0.85)    
plt.xlabel('Sepal_Length')
plt.ylabel('Petal_Length')
plt.colorbar()

# %%
plt.figure(figsize=(10, 6))       # to set the dimension o fthe graph ( 10 => width and 6 => height )

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='winter',alpha=0.85)    
plt.xlabel('Sepal_Length')
plt.ylabel('Petal_Length')
plt.colorbar()

# %% [markdown]
# # Annotations

# %%
batter = pd.read_csv('batter.csv')
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
sample_df = batter.head(100).sample(25,random_state=5)  # to take random 25 rows from the first 100 rows of the dataframe
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

# %%
# to describe the annotations in the graph
data_1 = [ 1,2,3,4]
data_2 = [5,6,7,8]
plt.scatter(data_1, data_2)
plt.text(1, 5, 'Point A', fontsize=12, color='red')  # Adding annotation at point (1,5)
# plt.text(x-axis wala point , y-axis wala point, jo name hme dena h usko ,uske additional features like color fontsize etc)

plt.text(2, 6, 'Point B', fontsize=10, color='green') 
plt.text(3, 7, 'Point C', fontsize=20, color='orange') 
plt.text(4, 8, 'Point D', fontdict={'fontsize':15, 'color':'blue'})  # Using a dictionary for font properties
# Out:
# Text(4, 8, 'Point D')

# %%
plt.figure(figsize=(14,7))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs']) 
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i],color='red',fontsize=12)

# %%
plt.figure(figsize=(14,7))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs']) 

plt.axhline(130,color='red',linestyle='--',label='Strike Rate Threshold')  # Adding a horizontal line at y=130
plt.axvline(30,color='blue',linestyle='--',label='Average Threshold')     #Addind a vertical line at x=25 

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i],color='red',fontsize=12)

# %% [markdown]
# # Subplots

# %%
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.figure(figsize=(15,6))
plt.scatter(batter['avg'],batter['strike_rate'],color='red')
plt.title('Batter info.')
plt.xlabel('Average')
plt.ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
# 2nd method for scatter plot (also use in subplot method)

plt,ax = plt.subplots(figsize=(15,6))
ax.scatter(batter['avg'],batter['strike_rate'],color='red')
ax.set_title('Batter info.')
ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,6))    # sharex remove coorindate of upper graph and only show coordinate of lower graph
ax[0].scatter(batter['avg'],batter['strike_rate'],color = 'green') 
ax[1].scatter(batter['avg'],batter['runs'],color = 'red')
ax[0].set_title("Average of batter vs Strike rate")
ax[0].set_xlabel("Average")
ax[0].set_ylabel('Strike Rate')

ax[1].set_title("Average vs Runs")
ax[1].set_xlabel("Average")
ax[1].set_ylabel("Runs")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,10))   
ax[0][0].scatter(batter['avg'],batter['strike_rate'],color = 'green') 
ax[0,1].scatter(batter['avg'],batter['runs'],color = 'red')
ax[0,0].set_title("Average of batter vs Strike rate")
ax[0,0].set_xlabel("Average")
ax[0,0].set_ylabel('Strike Rate')

ax[0,1].set_title("Average vs Runs")
ax[0,1].set_xlabel("Average")
ax[0,1].set_ylabel("Runs")

ax[1,0].set_title("Avg of batter")
ax[1,0].hist(batter['avg'])

ax[1,1].set_title("Runs of batter")
ax[1,1].hist(batter['runs'])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(2,1,1)         # no. of rows- no. of columns - position of the graph 
ax1.scatter(batter['avg'],batter['strike_rate'],color = 'green')

ax2 = fig.add_subplot(2,1,2)        # no. of rows- no. of columns - position of the graph 
ax2.hist(batter['avg'],color = 'orange')
# Out:
# (array([102., 125., 103.,  82.,  78.,  43.,  22.,  14.,   2.,   1.]),
#  array([ 0.        ,  5.56666667, 11.13333333, 16.7       , 22.26666667,
#         27.83333333, 33.4       , 38.96666667, 44.53333333, 50.1       ,
#         55.66666667]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 3-D Scatter plot

# %%
import matplotlib.pyplot as plt
batter

fig = plt.figure(figsize=(10,7))
ax = plt.subplot(projection='3d')
ax.scatter3D(batter['runs'],batter['avg'],batter['strike_rate'],color="red")
ax.set_title("Average and strike rate")
ax.set_xlabel("Runs")
ax.set_ylabel("Average")
ax.set_zlabel("Strike Rate")
# Out:
# Text(0.5, 0, 'Strike Rate')
